# %% [markdown]
# # Sparse imaging with LASSO
#
# This example generates a sparse signal and tries to recover it using lasso

# %%
from __future__ import print_function
from __future__ import division
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np
from scipy import misc
from IPython import display
from simulator import *
# %matplotlib inline

# %% [markdown]
# We generate an orthogonal matrix X and compute measurements = Xw+z where w is the vectorized format of the sparse image

# %%
measurements,X,I = simulate() 

# THE SETTINGS FOR THE IMAGE - PLEASE DO NOT CHANGE
height = 91
width = 120
imDims = (height, width)
sparsity = 476
numPixels = len(X[0])

plt.imshow(I, cmap=plt.cm.gray, interpolation='nearest');
plt.title('Original Sparse Image')
# Out:
# Text(0.5,1,'Original Sparse Image')

# %% [markdown]
# We plot matrix X:

# %%
chosenMaskToDisplay = 0
M0 = X[chosenMaskToDisplay].reshape((height,width))
plt.title('Matrix X')
plt.imshow(M0, cmap=plt.cm.gray, interpolation='nearest');

# %% [markdown]
# And here is the plot of measurement vector:

# %%
# measurements
plt.title('measurement vector (y)')
plt.plot(measurements)
plt.xlabel('measurement index')
plt.show()

# %% [markdown]
# We use lasso to recover the image:

# %%
def LASSO(imDims, measurements, X, _lambda):
    clf = linear_model.Lasso(alpha=_lambda)
    clf.fit(X,measurements)
    Ihat = clf.coef_.reshape(imDims)
    plt.title('estimated image')
    plt.imshow(Ihat, cmap=plt.cm.gray, interpolation='nearest') 
    return clf.coef_

# %% [markdown]
# Change the lasso regularization parameter to recover the image and report the value.

# %%
LASSO(imDims, measurements, X, _lambda=0.000000001)
# Out:
# array([-0.15135325,  0.00075921, -0.16403223, ...,  0.17085804,
#         0.18283628, -0.10982653])

# %%
LASSO(imDims, measurements, X, _lambda=0.000001)
# Out:
# array([-0.,  0., -0., ..., -0., -0.,  0.])

# %%
LASSO(imDims, measurements, X, _lambda=0.00001)
# Out:
# array([-0.,  0., -0., ..., -0., -0.,  0.])

# %%
LASSO(imDims, measurements, X, _lambda=0.0001)
# Out:
# array([-0.,  0., -0., ..., -0., -0.,  0.])

# %%
LASSO(imDims, measurements, X, _lambda=0.001)
# Out:
# array([-0., -0., -0., ..., -0., -0.,  0.])

# %% [markdown]
# ## Larger lambda, more zeros we will have, so larger lambda leads to more black pixels. Smaller lambda, less zeros we will have, so smaller lambda leads to more non-black pixels.
# ## If lambda is too large, it is too successful in suppressing the weights, making them all zeros, and we end up with an all-black image. If lambda is too small, then it cannot efficiently suppress the noises, and we end up with a image with noises.
